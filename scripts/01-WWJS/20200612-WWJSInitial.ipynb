# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Import-and-Load-Data" data-toc-modified-id="Import-and-Load-Data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Import and Load Data</a></span></li><li><span><a href="#What-Did-Jesus-Say?" data-toc-modified-id="What-Did-Jesus-Say?-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>What Did Jesus Say?</a></span><ul class="toc-item"><li><span><a href="#Basic-Processing" data-toc-modified-id="Basic-Processing-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Basic Processing</a></span></li><li><span><a href="#Proper-Nouns" data-toc-modified-id="Proper-Nouns-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Proper Nouns</a></span></li></ul></li></ul></div>

# %% [markdown]
# # WWJS
#
# What Would Jesus Say?<br>
# The bible is a very structured text. So there are only a very small number of verbs that are related with Jesus. This means we can encode all the types of responses he had into simple integers, and maybe train a classifier to see what Jesus may say.

# %% [markdown]
# ## Import and Load Data

# %%
import pandas as pd

import sys 
sys.path.append('../../data/')
from utils import load_book

# %%
books = {}
for book in ["Matthew", "Mark", "Luke", "John"]:
    books[book] = load_book(book, '../../data/new_testament/')
    books[book]["book"] = book

# %% [markdown]
# ## What Did Jesus Say?
#
# To get a grasp at our task, let's first try and take a look at what Jesus said.<br>
# To do so, we need to first be able to figure out who said what for each sentence.<br><br>
# Which is why we'll start by looking at every Proper Noun found in the first 4 books.<br>
# Then we'll try and match each pronoun to a proper noun.

# %% [markdown]
# ### Basic Processing

# %%
# Concatenate the 4 starting books
df = pd.concat(books.values()).reset_index(drop=True)

# %%
df
# Out:
#       verse  passage                                               text  \
# 0         1        1  The book of the generation of Jesus Christ, th...
# 1         1        2  Abraham begat Isaac; and Isaac begat Jacob; an...
# 2         1        3  And Judas begat Phares and Zara of Thamar; and...
# 3         1        4  And Aram begat Aminadab; and Aminadab begat Na...
# 4         1        5  And Salmon begat Booz of Rachab; and Booz bega...
# ...     ...      ...                                                ...
# 3774     21       21  Peter seeing him saith to Jesus, Lord, and wha...
# 3775     21       22  Jesus saith unto him, If I will that he tarry ...
# 3776     21       23  Then went this saying abroad among the brethre...
# 3777     21       24  This is the disciple which testifieth of these...
# 3778     21       25  And there are also many other things which Jes...
#
#          book
# 0     Matthew
# 1     Matthew
# 2     Matthew
# 3     Matthew
# 4     Matthew
# ...       ...
# 3774     John
# 3775     John
# 3776     John
# 3777     John
# 3778     John
#
# [3779 rows x 4 columns]

# %% [markdown]
# ### Proper Nouns

# %%
from nltk.tag import pos_tag

# %%
df['pos_tagged'] = df.text.apply(lambda s : pos_tag(s.split()))

# %%
def extract_tag(lst, target_tag):
    answer = []
    for word, tag in lst:
        if tag == target_tag:
            answer.append(word)
    return answer
df['NNP'] = df.pos_tagged.apply(lambda l : extract_tag(l, 'NNP'))

# %%
all_proper_nouns = set()
_ = df.NNP.apply(lambda l : all_proper_nouns.update(l))

# %%
all_proper_nouns
# Out:
# {'(as',
#  '(for',
#  '(he',
#  '(let',
#  '(which',
#  '(whoso',
#  'A',
#  'Aaron,',
#  'Abba,',
#  'Abel',
#  'Abia',
#  'Abia:',
#  'Abia;',
#  'Abiathar',
#  'Abide',
#  'Abilene,',
#  'Abiud',
#  'Abiud;',
#  'Abraham',
#  "Abraham's",
#  'Abraham,',
#  'Abraham.',
#  'Abraham:',
#  'Abraham?',
#  'Achaz',
#  'Achaz;',
#  'Achim',
#  'Achim;',
#  'Adam,',
#  'Addi,',
#  'Aenon',
#  'Afterward',
#  'Again',
#  'Again,',
#  'Agree',
#  'Ah,',
#  'Alexander',
#  'All',
#  'Alphaeus',
#  'Alphaeus,',
#  'Am',
#  'Amen.',
#  'Aminadab',
#  'Aminadab,',
#  'Aminadab;',
#  'Amon',
#  'Amon;',
#  'Amos,',
#  'And,',
#  'Andrew',
#  'Andrew,',
#  'Andrew:',
#  'Anna,',
#  'Annas',
#  'Answerest',
#  'Aram',
#  'Aram,',
#  'Aram;',
#  'Archelaus',
#  'Are',
#  'Arimathaea,',
#  'Arise,',
#  'Arise.',
#  'Arphaxad,',
#  'Art',
#  'Asa',
#  'Asa;',
#  'Aser:',
#  'Ask',
#  'Ask,',
#  'Augustus',
#  'Avenge',
#  'Away',
#  'Azor',
#  'Azor;',
#  'Babylon',
#  'Babylon,',
#  'Babylon:',
#  'Baptist',
#  "Baptist's",
#  'Baptist,',
#  'Baptist.',
#  'Baptist:',
#  'Baptist;',
#  'Barabbas',
#  'Barabbas,',
#  'Barabbas.',
#  'Barabbas:',
#  'Barachias,',
#  'Barjona:',
#  'Bartholomew,',
#  'Bartholomew;',
#  'Bartimaeus,',
#  'Be',
#  'Beelzebub',
#  'Beelzebub,',
#  'Beelzebub.',
#  'Behold',
#  'Behold,',
#  'Believe',
#  'Believest',
#  'Bethabara',
#  'Bethany',
#  'Bethany,',
#  'Bethany;',
#  'Bethesda,',
#  'Bethlehem',
#  'Bethlehem,',
#  'Bethlehem;',
#  'Bethphage',
#  'Bethphage,',
#  'Bethsaida',
#  'Bethsaida!',
#  'Bethsaida,',
#  'Bethsaida.',
#  'Bethsaida;',
#  'Beware',
#  'Bind',
#  'Bless',
#  'Blessed?',
#  'Boanerges,',
#  'Booz',
#  'Booz,',
#  'Bring',
#  'Brother,',
#  'But,',
#  'Buy',
#  'Caesar',
#  "Caesar's",
#  "Caesar's,",
#  "Caesar's.",
#  "Caesar's;",
#  'Caesar,',
#  'Caesar.',
#  'Caesarea',
#  'Caiaphas',
#  'Caiaphas,',
#  'Cainan,',
#  'Calvary,',
#  'Came',
#  'Can',
#  'Cana',
#  'Canaan',
#  'Canaanite,',
#  'Capernaum',
#  'Capernaum,',
#  'Capernaum.',
#  'Capernaum:',
#  'Capernaum;',
#  'Carry',
#  'Cedron,',
#  'Cephas,',
#  'Children,',
#  'Chorazin!',
#  'Christ',
#  'Christ,',
#  'Christ.',
#  'Christ:',
#  'Christ;',
#  'Christ?',
#  'Christs,',
#  'Chuza',
#  'Cleopas,',
#  'Cleophas,',
#  'Come',
#  'Come,',
#  'Come.',
#  'Come;',
#  'Comforter',
#  'Comforter,',
#  'Command',
#  'Concerning',
#  'Consider',
#  'Corban,',
#  'Cosam,',
#  'Cover',
#  'Crucify',
#  'Cyrene,',
#  'Cyrenian,',
#  'Cyrenius',
#  'Dalmanutha.',
#  'Damsel,',
#  'Daniel',
#  'Daughter,',
#  'David',
#  "David's",
#  'David,',
#  'David.',
#  'David:',
#  'David:)',
#  'David;',
#  'David?',
#  'Decapolis',
#  'Decapolis,',
#  'Decapolis.',
#  'Declare',
#  'Defraud',
#  'Depart',
#  'Destroy',
#  'Did',
#  'Didymus,',
#  'Do',
#  'Dost',
#  'Doth',
#  'Draw',
#  'Drink',
#  'Egypt',
#  'Egypt,',
#  'Egypt:',
#  'Eleazar',
#  'Eleazar;',
#  'Eli,',
#  'Eliakim',
#  'Eliakim,',
#  'Eliakim;',
#  'Elias',
#  'Elias,',
#  'Elias.',
#  'Elias:',
#  'Elias;',
#  'Elias?',
#  'Eliezer,',
#  'Elisabeth',
#  "Elisabeth's",
#  'Elisabeth,',
#  'Elisabeth.',
#  'Eliseus',
#  'Eliud',
#  'Eliud;',
#  'Elmodam,',
#  'Eloi,',
#  'Emmanuel,',
#  'Emmaus,',
#  'Enoch,',
#  'Enos,',
#  'Enter',
#  'Ephphatha,',
#  'Ephraim,',
#  'Er,',
#  'Esaias',
#  'Esaias,',
#  'Esaias.',
#  'Esli,',
#  'Esrom',
#  'Esrom,',
#  'Esrom;',
#  'Every',
#  'Exact',
#  'Ezekias',
#  'Ezekias;',
#  'Fall',
#  'Father',
#  "Father's",
#  "Father's,",
#  'Father,',
#  'Father,)',
#  'Father.',
#  'Father:',
#  'Father;',
#  'Father?',
#  'Fear',
#  'Feed',
#  'Fill',
#  'Five,',
#  'Follow',
#  'For,',
#  'Forbid',
#  'Forty',
#  'Friend,',
#  'From',
#  'Full',
#  'Gabbatha.',
#  'Gabriel',
#  'Gabriel,',
#  'Gadarenes',
#  'Gadarenes,',
#  'Gadarenes.',
#  'Galilaean,',
#  'Galilaean.',
#  'Galilaeans,',
#  'Galilee',
#  'Galilee,',
#  'Galilee.',
#  'Galilee:',
#  'Galilee;',
#  'Galilee?',
#  'Gather',
#  'Gennesaret,',
#  'Gennesaret.',
#  'Gentiles',
#  'Gentiles,',
#  'Gentiles.',
#  'Gentiles:',
#  'Gentiles;',
#  'Gentiles?',
#  'Gergesenes,',
#  'Get',
#  'Gethsemane,',
#  'Gethsemane:',
#  'Ghost',
#  'Ghost,',
#  'Ghost.',
#  'Ghost:',
#  'Give',
#  'Give,',
#  'Go',
#  'Go,',
#  'Go.',
#  'God',
#  'God!',
#  "God's",
#  "God's.",
#  'God,',
#  'God.',
#  'God:',
#  'God;',
#  'God?',
#  'Golgotha,',
#  'Golgotha:',
#  'Gomorrha',
#  'Good',
#  'Governor,',
#  'Grant',
#  'Greater',
#  'Greek,',
#  'Greeks',
#  'Hail,',
#  'Hallowed',
#  'Hath',
#  'Hear',
#  'Hear,',
#  'Hearest',
#  'Hearken',
#  'Hearken;',
#  'Heaven',
#  'Heber,',
#  'Hebrew',
#  'Hebrew,',
#  'Heli,',
#  'Henceforth',
#  'Her',
#  'Hereafter',
#  'Herein',
#  'Herod',
#  "Herod's",
#  'Herod,',
#  'Herod.',
#  'Herod:',
#  'Herodians,',
#  'Herodias',
#  "Herodias'",
#  'Highest',
#  'Highest:',
#  'Himself',
#  'Hitherto',
#  'Hold',
#  'Holy',
#  'Honour',
#  'Hosanna',
#  'Hosanna:',
#  'Hosanna;',
#  'How',
#  'Howbeit',
#  'I,',
#  'I;',
#  'I?',
#  'Idumaea,',
#  'Inasmuch',
#  'Increase',
#  'Is',
#  'Isaac',
#  'Isaac,',
#  'Isaac;',
#  'Iscariot',
#  'Iscariot,',
#  'Israel',
#  'Israel,',
#  'Israel.',
#  'Israel:',
#  'Israel;',
#  'Israelite',
#  'Ituraea',
#  'JESUS',
#  'JESUS,',
#  'JESUS.',
#  'JESUS:',
#  'JEWS.',
#  'Jacob',
#  "Jacob's",
#  'Jacob,',
#  'Jacob.',
#  'Jacob;',
#  'Jacob?',
#  'Jairus',
#  'Jairus,',
#  'James',
#  'James,',
#  'James.',
#  'James;',
#  'Janna,',
#  'Jared,',
#  'Jechonias',
#  'Jeremias,',
#  'Jeremy',
#  'Jericho',
#  'Jericho,',
#  'Jericho.',
#  'Jericho:',
#  'Jerusalem',
#  'Jerusalem,',
#  'Jerusalem.',
#  'Jerusalem:',
#  'Jerusalem;',
#  'Jerusalem?',
#  'Jesse',
#  'Jesse,',
#  'Jesse;',
#  'Jesus',
#  "Jesus'",
#  'Jesus,',
#  'Jesus.',
#  'Jesus:',
#  "Jew's",
#  'Jew,',
#  'Jew?',
#  'Jewry,',
#  'Jews',
#  'Jews!',
#  "Jews'",
#  'Jews,',
#  'Jews.',
#  'Jews:',
#  'Jews;',
#  'Jews?',
#  'Joanna',
#  'Joanna,',
#  'Joatham',
#  'Joatham;',
#  'John',
#  "John's",
#  'John,',
#  'John.',
#  'John:',
#  'Jona:',
#  'Jonan,',
#  'Jonas',
#  'Jonas,',
#  'Jonas.',
#  'Jonas:',
#  'Jonas;',
#  'Joram',
#  'Joram;',
#  'Jordan',
#  'Jordan,',
#  'Jordan.',
#  'Jordan:',
#  'Jordan;',
#  'Jorim,',
#  'Josaphat',
#  'Josaphat;',
#  'Jose,',
#  'Joseph',
#  "Joseph's",
#  'Joseph,',
#  'Joseph.',
#  'Joses',
#  'Joses,',
#  'Josias',
#  'Josias;',
#  'Juda,',
#  'Juda:',
#  'Juda;',
#  'Judaea',
#  'Judaea,',
#  'Judaea.',
#  'Judaea:',
#  'Judaea;',
#  'Judas',
#  'Judas,',
#  'Judas?',
#  'Judge',
#  'KING',
#  'King',
#  'King!',
#  'King.',
#  'King?',
#  'Know',
#  'Knowest',
#  'LORD',
#  'LORD,',
#  'LORD.',
#  'Labour',
#  'Lamb',
#  'Lamech,',
#  'Latin,',
#  'Latin.',
#  'Launch',
#  'Lay',
#  'Lazarus',
#  'Lazarus,',
#  'Lazarus.',
#  'Lebbaeus,',
#  'Legion:',
#  'Lest',
#  'Let',
#  'Levi',
#  'Levi,',
#  'Lift',
#  'Light,',
#  'Light.',
#  'Likewise',
#  'Lo',
#  'Lo,',
#  'Loose',
#  'Lord',
#  "Lord's",
#  'Lord,',
#  'Lord.',
#  'Lord:',
#  'Lord;',
#  'Lord;)',
#  'Lord?',
#  'Lot',
#  "Lot's",
#  'Lot;',
#  'Lovest',
#  'Lysanias',
#  'Maath,',
#  'Magdala.',
#  'Magdalene',
#  'Magdalene,',
#  'Magdalene.',
#  'Maid,',
#  'Make',
#  'Malchus.',
#  'Maleleel,',
#  'Man',
#  'Man,',
#  'Manasses',
#  'Manasses;',
#  'Martha',
#  'Martha,',
#  'Martha.',
#  'Marvel',
#  'Mary',
#  'Mary,',
#  'Mary.',
#  'Mary:',
#  'Mary?',
#  'Master',
#  'Master,',
#  'Master,)',
#  'Master.',
#  'Mathusala,',
#  'Mattatha,',
#  'Mattathias,',
#  'Matthan',
#  'Matthan;',
#  'Matthat,',
#  'Matthew',
#  'Matthew,',
#  'Melchi,',
#  'Melea,',
#  "Men's",
#  'Menan,',
#  'Messias',
#  'Messias,',
#  'Moses',
#  "Moses'",
#  'Moses,',
#  'Moses:',
#  'Murmur',
#  'My',
#  'NAZARETH',
#  'Naaman',
#  'Naasson',
#  'Naasson,',
#  'Naasson;',
#  'Nachor,',
#  'Nagge,',
#  'Nain;',
#  'Naked,',
#  'Nathan,',
#  'Nathanael',
#  'Nathanael,',
#  'Nation',
#  'Naum,',
#  'Nay,',
#  'Nay:',
#  'Nay;',
#  'Nazareth',
#  'Nazareth,',
#  'Nazareth.',
#  'Nazareth:',
#  'Nazareth?',
#  'Neither',
#  'Nephthalim,',
#  'Nephthalim:',
#  'Neri,',
#  'Never',
#  'Nicodemus',
#  'Nicodemus,',
#  'Nineve',
#  'Nineveh',
#  'Ninevites,',
#  'No',
#  'No,',
#  'Noe',
#  'Noe,',
#  'Nothing.',
#  'O',
#  'OF',
#  'Obed',
#  'Obed,',
#  'Occupy',
#  'Olives,',
#  'Olives.',
#  'Olives;',
#  'Others',
#  'Out',
#  'Ozias',
#  'Ozias;',
#  'Passover.',
#  'Pavement,',
#  'Pay',
#  'Peace',
#  'Peace,',
#  'Perceive',
#  'Peter',
#  "Peter's",
#  'Peter,',
#  'Peter,)',
#  'Peter.',
#  'Peter:',
#  'Peter;',
#  'Phalec,',
#  'Phanuel,',
#  'Phares',
#  'Phares,',
#  'Pharisee',
#  "Pharisee's",
#  'Pharisee,',
#  'Pharisees',
#  'Pharisees!',
#  'Pharisees,',
#  'Pharisees.',
#  'Pharisees;',
#  'Philip',
#  "Philip's",
#  'Philip,',
#  'Philip?',
#  'Philippi,',
#  'Philippi:',
#  'Physician,',
#  'Pilate',
#  'Pilate,',
#  'Pilate.',
#  'Pontius',
#  'Praetorium;',
#  'Pray',
#  'Prepare',
#  'Prophesy',
#  'Prophesy,',
#  'Prophesy:',
#  'Prophet.',
#  'Psalms,',
#  'Put',
#  'Rabbi,',
#  'Rabbi.',
#  'Rabbi:',
#  'Rabboni;',
#  'Raca,',
#  'Rachab;',
#  'Rachel',
#  'Ragau,',
#  'Rama',
#  'Reach',
#  'Receive',
#  'Rejoice',
#  'Rejoice,',
#  'Remember',
#  'Remove',
#  'Render',
#  'Repent',
#  'Repent:',
#  'Rhesa,',
#  'Rise',
#  'Rise,',
#  'Roboam',
#  'Roboam;',
#  'Rufus,',
#  'Ruth;',
#  'Sadducees',
#  'Sadducees,',
#  'Sadducees.',
#  'Sadducees?',
#  'Sadoc',
#  'Sadoc;',
#  'Said',
#  'Sala,',
#  'Salathiel',
#  'Salathiel,',
#  'Salathiel;',
#  'Salim,',
#  'Salmon',
#  'Salmon,',
#  'Salmon;',
#  'Salome,',
#  'Salome;',
#  'Salt',
#  'Samaria',
#  'Samaria,',
#  'Samaria.',
#  'Samaria?',
#  'Samaritan,',
#  'Samaritan.',
#  'Samaritans',
#  'Samaritans,',
#  'Samaritans.',
#  'Sarepta,',
#  'Saruch,',
#  'Satan',
#  'Satan,',
#  'Satan:',
#  'Satan;',
#  'Satan?',
#  'Save',
#  'Saviour',
#  'Saviour,',
#  'Say',
#  'Sayest',
#  'Saying,',
#  'Search',
#  'Search,',
#  'See',
#  'Seest',
#  'Sell',
#  'Sem,',
#  'Semei,',
#  'Send',
#  'Sent.)',
#  'Seth,',
#  'Seven,',
#  'Seven.',
#  'Shall',
#  'She,',
#  'Shew',
#  'Shouldest',
#  'Sidon',
#  'Sidon,',
#  'Sidon.',
#  'Siloam',
#  'Siloam,',
#  'Simeon',
#  'Simeon,',
#  'Simeon;',
#  'Simon',
#  "Simon's",
#  "Simon's,",
#  'Simon,',
#  'Simon.',
#  'Simon:',
#  'Simon?',
#  'Sion,',
#  'Sion:',
#  'Sir,',
#  'Sit',
#  'Sleep',
#  'Sodom',
#  'Sodom,',
#  'Solomon',
#  "Solomon's",
#  'Solomon;',
#  'Somebody',
#  'Son',
#  'Son,',
#  'Son.',
#  'Son:',
#  'Son;',
#  'Soul,',
#  'Speakest',
#  'Spirit',
#  'Spirit,',
#  'Spirit.',
#  'Spirit:',
#  'Stand',
#  'Stretch',
#  'Suffer',
#  'Sufficient',
#  'Suppose',
#  'Surely',
#  'Susanna,',
#  'Swear',
#  'Sychar,',
#  'Syria.)',
#  'Syria:',
#  'Syrian.',
#  'THE',
#  'THERE',
#  'THIS',
#  'Take',
#  'Take,',
#  'Talitha',
#  'Tell',
#  'Thaddaeus,',
#  'Thaddaeus;',
#  'Thamar;',
#  'Thara,',
#  'Thefts,',
#  'Therefore',
#  'Thine',
#  'Think',
#  'Thinkest',
#  'Thomas',
#  'Thomas,',
#  'Thou',
#  'Thus',
#  'Thy',
#  'Tiberias',
#  'Tiberias.',
#  'Tiberias;',
#  'Tiberius',
#  'Till',
#  'Timaeus,',
#  'Took',
#  'Touch',
#  'Trachonitis,',
#  'Trouble',
#  'Truly',
#  'Truth,',
#  'Twelve.',
#  'Tyre',
#  'Unto',
#  'Urias;',
#  'Verily',
#  'Verily,',
#  'Walk',
#  'Watch',
#  'Watch.',
#  'Weep',
#  'Well',
#  'Well,',
#  'Were',
#  'What,',
#  'Whatsoever',
#  'Whence',
#  'Where',
#  'Where,',
#  'Whereby',
#  'Wherefore',
#  'Wherefore,',
#  'Wheresoever',
#  'Whereunto',
#  'Wherewithal',
#  'Whether',
#  'Which',
#  'Which?',
#  'Whither',
#  'Who',
#  'Whom',
#  'Whomsoever',
#  'Whose',
#  'Whoso',
#  'Whosoever',
#  'Why,',
#  'Will',
#  'Wilt',
#  'Woe',
#  'Woman,',
#  'Word',
#  'Word,',
#  'Write',
#  'Ye',
#  'Yea',
#  'Yea,',
#  'Yea;',
#  'Yes,',
#  'Yes.',
#  'Young',
#  'Zabulon',
#  'Zabulon,',
#  'Zacchaeus',
#  'Zacchaeus,',
#  'Zacharias',
#  'Zacharias,',
#  'Zacharias:',
#  'Zara',
#  'Zebedee',
#  'Zebedee,',
#  'Zebedees',
#  'Zelotes,',
#  'Zorobabel',
#  'Zorobabel,',
#  'Zorobabel;',
#  'bridechamber',
#  'thou',
#  'unto',
#  'ye',
#  'yea;'}
